# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# %cd /content/gdrive/MyDrive/writing-feedback

# %%
# %%capture
# !pip install -r requirements.txt
# !python utils/setup.py

# %%
import wandb
wandb.login()

# %%
# !python train_arg_model.py

# %%
# !python train_essay_feedback.py debug=true wandb=false epochs=200 nhead=4 num_encoder_layers=2 num_decoder_layers=2
